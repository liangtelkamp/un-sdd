# %%
# Set sys path to root directory
import sys
sys.path.append("..")
from modules.utils.eval_utils import evaluate_pii_detection, evaluate_non_pii_table
from modules.utils.general_utils import load_json_data

# %%
# Path to PII file to evaluate
pii_path = "C:/Users/VN/Documents/GitHub/detecting-sensitive-data/modules/test/personal.json"

# Load PII data
pii_data = load_json_data(pii_path)

# Assert error if pii_data is not dict
assert type(pii_data) == dict, "PII data is not a dict"

# %%
evaluate_pii_detection(pii_data, "Unsloth/gemma-2-9b-it", show_fps=True, show_fns=True)
# Out:
# ### False Positives
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | Table                                             | Column                                       |   Ground Truth | Prediction       |
# +===================================================+==============================================+================+==================+
# | ConfigurationsTemplate_1.csv                      | default_gateway                              |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | ConfigurationsTemplate_1.csv                      | purchased_at                                 |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | ConfigurationsTemplate_1.csv                      | configuration_interfaces                     |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 1598659200.csv                                    | IndvId                                       |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 1598659200.csv                                    | UserId                                       |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 1598659200.csv                                    | PageLatLong                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | master2_20.csv                                    | playerID                                     |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | master2_20.csv                                    | debut                                        |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | master2_20.csv                                    | bbrefID                                      |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 3_BIKE.csv                                        | StationAddress                               |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 3_BIKE.csv                                        | lat                                          |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 3_BIKE.csv                                        | lng                                          |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Contact ID                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Last Contacted                               |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Standard 9 months                            |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Standard 14 weeks                            |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Standard 16 months                           |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Standard 5 years                             |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Functional 6 weeks                           |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Functional 10 weeks                          |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Functional 14 weeks                          |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Functional 9 months                          |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | example_282.csv                                   | Functional 16 months                         |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | master2_4.csv                                     | playerID                                     |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | master2_4.csv                                     | debut                                        |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | master2_4.csv                                     | bbrefID                                      |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | SLO1_2001.csv                                     | Current club id                              |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | parties-addresses_2.csv                           | street                                       |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | parties-addresses_2.csv                           | postal_code                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | test-misc_6.csv                                   | HIHI                                         |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 01%20-%20Individual.csv                           | FamilyId                                     |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 01%20-%20Individual.csv                           | PersonId                                     |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 01%20-%20Individual.csv                           | GraduationDate                               |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | 01%20-%20Individual.csv                           | ^New Category Test^New Date Attribute Test^D |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | Customer_81.csv                                   | CustomerId                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | Customer_81.csv                                   | Fax                                          |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | Customer_81.csv                                   | SupportRepId                                 |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | metadata_file2.csv                                | sample_submitter_id                          |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | addresses_version_1.csv                           | postal_code                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | res.partner_14.csv                                | name                                         |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | res.partner_14.csv                                | email                                        |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | non_crim_15.csv                                   | Status Date                                  |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | non_crim_15.csv                                   | DL Number                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | education.application_15.csv                      | admission_date                               |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | education.application_15.csv                      | father_name/id                               |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | education.application_15.csv                      | guardian_name/id                             |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | felony2020-02-12%20at%2012.15.38%20PM%20110_1.csv | Status Date                                  |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | felony2020-02-12%20at%2012.15.38%20PM%20110_1.csv | DL Number                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | EMPLOYEES_12.csv                                  | EMPLOYEE_ID                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | EMPLOYEES_12.csv                                  | HIRE_DATE                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | EMPLOYEES_12.csv                                  | MANAGER_ID                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | deidentified_demographics_1.csv                   | deidentified_demographics_id                 |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | patients_16.csv                                   | patient_id                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | patients_16.csv                                   | onset_date                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | patients_16.csv                                   | phone_number                                 |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | EMPLOYEES_9.csv                                   | EMPLOYEE_ID                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | EMPLOYEES_9.csv                                   | HIRE_DATE                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | EMPLOYEES_9.csv                                   | MANAGER_ID                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | ScheduleE_9.csv                                   | ScheduleEId                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | ScheduleE_9.csv                                   | LenderCommitteeContactId                     |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | submitterId                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | address                                      |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | longitude                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | latitude                                     |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | locationText                                 |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | addressInfo                                  |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | properties_109.csv                                | reviewerId                                   |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | res.bank_384.csv                                  | zip                                          |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | res.bank_384.csv                                  | street                                       |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | res.bank_384.csv                                  | email                                        |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | res.bank_384.csv                                  | phone                                        |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | hospitals_6.csv                                   | address                                      |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | hospitals_6.csv                                   | telephone                                    |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | hospitals_6.csv                                   | email                                        |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | hospitals_6.csv                                   | lattitude                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | hospitals_6.csv                                   | longitude                                    |              0 | MEDIUM_SENSITIVE |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
# | msf.csv                                           | NationalId                                   |              0 | HIGH_SENSITIVE   |
# +---------------------------------------------------+----------------------------------------------+----------------+------------------+
#
# ### False Negatives
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | Table                                             | Column                  |   Ground Truth | Prediction    |
# +===================================================+=========================+================+===============+
# | address_import_update_3.csv                       | middlename              |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | example_282.csv                                   | Language Preference     |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | longitudinal-data-import_1.csv                    | ethnicity               |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | longitudinal-data-import_1.csv                    | race                    |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | longitudinal-data-import_1.csv                    | sex                     |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | example_332.csv                                   | Middle names            |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | 01%20-%20Individual.csv                           | NickName                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | 01%20-%20Individual.csv                           | MiddleName              |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | 01%20-%20Individual.csv                           | MaritalStatus           |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | non_crim_15.csv                                   | Middle Name             |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | non_crim_15.csv                                   | Race                    |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | education.application_15.csv                      | middle_name             |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | education.application_15.csv                      | street2                 |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | felony2020-02-12%20at%2012.15.38%20PM%20110_1.csv | Middle Name             |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | felony2020-02-12%20at%2012.15.38%20PM%20110_1.csv | Race                    |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | felony2020-02-12%20at%2012.15.38%20PM%20110_1.csv | Sex                     |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | ethnicity               |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | race___0                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | race___1                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | race___2                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | race___3                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | race___4                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | race___5                |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | deidentified_demographics_1.csv                   | sex                     |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | aft_test_data_geocoded_1.csv                      | RACE                    |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | aft_test_data_geocoded_1.csv                      | PROVIDER_ID             |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | patients_16.csv                                   | race                    |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | ScheduleE_9.csv                                   | LenderMiddleName        |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | ScheduleE_9.csv                                   | LenderLastOrCompanyName |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | ScheduleE_9.csv                                   | LenderAddressLine2      |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | ScheduleE_9.csv                                   | ReportUID               |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | msf.csv                                           | PreferredName           |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# | msf.csv                                           | Sex                     |              1 | NON_SENSITIVE |
# +---------------------------------------------------+-------------------------+----------------+---------------+
# {'precision': 0.7072243346007605,
#  'recall': 0.8493150684931506,
#  'f1': 0.7717842323651453,
#  'accuracy': 0.9167927382753404}
